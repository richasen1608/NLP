# %%
import numpy as np
import pandas as pd
import nltk

# %%
import nltk

nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
amazon_df=pd.read_csv('amazon_product.csv')
amazon_df.head()
# Out:
#    id                                              Title  \
# 0   1   Swissmar Capstore Select Storage Rack for 18-...
# 1   2   Gemini200 Delta CV-880 Gold Crown Livery Airc...
# 2   5   Superior Threads 10501-2172 Magnifico Cream P...
# 3   6            Fashion Angels Color Rox Hair Chox Kit
# 4   8   Union Creative Giant Killing Figure 05: Daisu...
#
#                                          Description  \
# 0  Swissmar's capstore select 18 storage unit kee...
# 1  Welcome to the exciting world of GeminiJets! O...
# 2  For quilting and embroidery, this product is m...
# 3  Experiment with the haute trend of hair chalki...
# 4  From Union Creative. Turn your display shelf i...
#
#                                             Category
# 0   Home & Kitchen Kitchen & Dining Kitchen Utens...
# 1   Toys & Games Hobbies Models & Model Kits Pre-...
# 2   Arts, Crafts & Sewing Sewing Thread & Floss S...
# 3   Beauty & Personal Care Hair Care Hair Colorin...
# ...

# %%
amazon_df.drop('id',axis=1,inplace=True)
amazon_df.head()
# Out:
#                                                Title  \
# 0   Swissmar Capstore Select Storage Rack for 18-...
# 1   Gemini200 Delta CV-880 Gold Crown Livery Airc...
# 2   Superior Threads 10501-2172 Magnifico Cream P...
# 3            Fashion Angels Color Rox Hair Chox Kit
# 4   Union Creative Giant Killing Figure 05: Daisu...
#
#                                          Description  \
# 0  Swissmar's capstore select 18 storage unit kee...
# 1  Welcome to the exciting world of GeminiJets! O...
# 2  For quilting and embroidery, this product is m...
# 3  Experiment with the haute trend of hair chalki...
# 4  From Union Creative. Turn your display shelf i...
#
#                                             Category
# 0   Home & Kitchen Kitchen & Dining Kitchen Utens...
# 1   Toys & Games Hobbies Models & Model Kits Pre-...
# 2   Arts, Crafts & Sewing Sewing Thread & Floss S...
# 3   Beauty & Personal Care Hair Care Hair Colorin...
# 4   Toys & Games › Action Figures & Statues › Sta...

# %%
amazon_df.isnull().sum()
# Out:
# Title          0
# Description    0
# Category       0
# dtype: int64

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer=SnowballStemmer('english')
def tokenize_stem(text):
    tokens=nltk.word_tokenize(text.lower())
    stemmed=[ stemmer.stem(w) for w in tokens ]
    return" ".join(stemmed)

# %%
amazon_df['stemmed_tokens']=amazon_df.apply(lambda row: tokenize_stem(row['Title'] + " "+row['Description']),axis=1)

# %%
amazon_df.head()
# Out:
#                                                Title  \
# 0   Swissmar Capstore Select Storage Rack for 18-...
# 1   Gemini200 Delta CV-880 Gold Crown Livery Airc...
# 2   Superior Threads 10501-2172 Magnifico Cream P...
# 3            Fashion Angels Color Rox Hair Chox Kit
# 4   Union Creative Giant Killing Figure 05: Daisu...
#
#                                          Description  \
# 0  Swissmar's capstore select 18 storage unit kee...
# 1  Welcome to the exciting world of GeminiJets! O...
# 2  For quilting and embroidery, this product is m...
# 3  Experiment with the haute trend of hair chalki...
# 4  From Union Creative. Turn your display shelf i...
#
#                                             Category  \
# 0   Home & Kitchen Kitchen & Dining Kitchen Utens...
# 1   Toys & Games Hobbies Models & Model Kits Pre-...
# 2   Arts, Crafts & Sewing Sewing Thread & Floss S...
# 3   Beauty & Personal Care Hair Care Hair Colorin...
# ...

# %%
# Download required NLTK data
nltk.download('punkt')  # Download 'punkt' instead of 'punkt_tab'
nltk.download('stopwords') # Download stop words if needed


# Apply stemming and tokenization to create the 'stemmed_tokens' column
amazon_df['stemmed_tokens'] = amazon_df.apply(lambda row: tokenize_stem(row['Title'] + " " + row['Description']), axis=1)

# Initialize TF-IDF Vectorizer
tfidf = TfidfVectorizer(tokenizer=tokenize_stem)

# Define function to calculate cosine similarity
def calculate_cosine_similarity(txt1, txt2):
    matrix = tfidf.fit_transform([txt1, txt2])
    return cosine_similarity(matrix)[0][1]  # Extract similarity score

# Define search function
def search_product(query):
    query_stemmed = tokenize_stem(query)
    amazon_df['similarity'] = amazon_df['stemmed_tokens'].apply(lambda x: calculate_cosine_similarity(query_stemmed, x))
    results = amazon_df.sort_values(by=['similarity'], ascending=False).head(10)
    return results[['Title', 'Description', 'similarity']]

# Perform the search
search_product('Swissmar Capstore Select Storage Rack for 18-Pack')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
#                                                  Title  \
# 475          Pacon Spectra Glitter Sparkling Crystals
# 463   Versio Mobile 3-Pack Screen Protector for LG ...
# 593   Qmadix QM-SPHTC6410 Screen Protector for HTC ...
# 526      Titan Classic Spandex Dreadlock Cap, Regular
# 177   Sargent Art 22-7099 6-Count 8-Ounce Fluoresce...
# 0     Swissmar Capstore Select Storage Rack for 18-...
# 147   Martha Stewart Crafts 32802 Stencil Brushes (...
# 110   Core Products Elastic Criss Cross Back Suppor...
# 384   Visol Ferrara Red Cigar Case - Holds 2-3 Cigars
# ...

# %%
search_product('Swissmar Capstore Select Storage Rack for 18-Pack')
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:517: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
#                                                  Title  \
# 475          Pacon Spectra Glitter Sparkling Crystals
# 463   Versio Mobile 3-Pack Screen Protector for LG ...
# 593   Qmadix QM-SPHTC6410 Screen Protector for HTC ...
# 526      Titan Classic Spandex Dreadlock Cap, Regular
# 177   Sargent Art 22-7099 6-Count 8-Ounce Fluoresce...
# 0     Swissmar Capstore Select Storage Rack for 18-...
# 147   Martha Stewart Crafts 32802 Stencil Brushes (...
# 110   Core Products Elastic Criss Cross Back Suppor...
# 384   Visol Ferrara Red Cigar Case - Holds 2-3 Cigars
# 13    BRUT After Shave Classic Fragrance 5 oz (Pack...
#
#                                            Description  similarity
# 475  Change all to: Spectra Glitter, Sparkling Crys...    0.851907
# ...

# %%
amazon_df['Title'][0]
# Out:
# ' Swissmar Capstore Select Storage Rack for 18-Pack '
